# %% [markdown]
# #PRACTICAL QUESTIONS
#
# ```
# [# This is formatted as code](https://)
# ```

# %%
#1.Write a code to create a string with your name and print it.

name = "sarvesh"
print(f"My name is {name}.")
# Out:
# My name is sarvesh.

# %%
# 2. Write a code to find the length of the string "Hello World".

string = "Hello World"
len(string)
# Out:
# 11

# %%
# 3. Write a code to slice the first 3 characters from the string "Python Programming".

text = "Python Programming"
text[0:3]
# Out:
# 'Pyt'

# %%
# 4. Write a code to convert the string "hello" to uppercase.

a = "hello"
a.upper()
# Out:
# 'HELLO'

# %%
# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple".

text = "I like apple"
text.replace("apple","orange")
# Out:
# 'I like orange'

# %%
# 6. Write a code to create a list with numbers I to 5 and print it.

number = list(range(1,6))
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. Write a code to append the number 10 to the list (1, 2, 3, 4].

list = [1,2,3,4]
list.append(10)
list

# %%
# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].

number_list = [1,2,3,4,5]
number_list.remove(3)
number_list

# %%
# 9. Write a code to access the second element in the list ('a', 'b', 'c, 'd'].

lis = ['a','b','c','d']
lis[1]

# %%
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

lis = [10,20,30,40,50]
lis.reverse()
lis

# %%
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.
a = (100, 200, 300)
print(a)

# %%
# 12.Write a code to access the second-to-last element of the tuple (red', 'green', 'blue', yellow).
colors = ('red', 'green', 'blue', 'yellow')
colors[1:]

# %%
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15).


given_tuple = (10,20,5,15)
min(given_tuple)

# %%
# 14. Write a code to find the index of the element "cat" in the tuple (dog', 'cat', rabbit').

given_tuple = ("dog","cat","rabbit")
given_tuple.index("cat")

# %%
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

fruits = ("mango", "dragon fruit", "pineapple","kiwi")
if 'kiwi' in fruits:
    print("Kiwi is in the tuple.")
else:
    print("Kiwi is not in the tuple.")

# %%
#16. Write a code to create a set with the elements 'a', 'b', 'c' and print it.

req_set = {'a', 'b', 'c'}
print(req_set)

# %%
#17. Write a code to clear all elements from the set {1, 2, 3, 4, 5}.

req_set = {'a', 'b', 'c','d'}
req_set.clear()
req_set
# Out:
# set()

# %%
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

my_set = {1,2,3,4}
my_set.remove(4)
my_set
# Out:
# {1, 2, 3}

# %%
#19. Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.

set1 = {1, 2, 3}
set2 = {3, 4, 5}

union_set = set1|set2
print(union_set)

# %%
# 20. Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.

set1 = {1, 2, 3}
set2 = {2, 3, 4}

intersection_set = set1&set2
print(intersection_set)

# %%
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

d = {"name": "Sarvesh", "age": 20 , "city" : "pune"}

print(d)

# %%
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary {name: 'John', 'age': 25}.

d = {"Name" : "John","age" : 25}
d["country"] = "usa"
print(d)

# %%
# 23. Write a code to access the value associated with the key "name" in the dictionary {'name: 'Alice', age: 30}.

d = {'name': 'Alice', 'age': 30}
d['name']

# %%
# 24. Write a code to remove the key "age" from the dictionary {'name: 'Bob', 'age: 22, 'city: 'New York'}.

d = {'name': 'Bob', 'age': 22, 'city': 'New York'}
d.pop('age')
d

# %%
# 25. Write a code to check if the key "city" exists in the dictionary {'name: 'Alice, 'city: 'Paris'}.

d = {"name": 'Alice', "city": 'Paris'}
print("city" in d)
# Out:
# True

# %%
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.

#  list
req_list= ["curriculum","pwskills",2,3.2]

#  tuple
req_tuple = ('apple', 'cocoa', 'kiwi')

# dictionary
req_dict = {'name': 'sarvesh', 'age': 20, 'sex': 'male'}

print("List:", req_list)
print("Tuple:", req_tuple)
print("Dictionary:", req_dict)

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)

req_list = [5,26,45,83,98]
req_list.sort()
req_list

# %%
# 28. Write a code to create a list with strings and print the element at the third index.

req_list = ["dragon fruit","flour","dandelion", 'date', 'strawberry']
print("Element at 3rd index:", req_list[3])

# %%
# 29. Write a code to combine two dictionaries into one and print the result.

dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
dict1.update(dict2)
print("Combined Dictionary:", dict1)

# %%
# 30. Write a code to convert a list of strings into a set.

req_string = ["pwskills","upskill", "data science","generative ai"]
req_string = set(req_string)
print("set:",req_string)

# %% [markdown]
# ## #THEORY QUESTIONS

# %% [markdown]
# 1. What are data structures, and why are they important?
#
# ---> They provide various ways to store, access, and manipulate data according to specific needs and organize data efficiently

# %% [markdown]
# 2. Explain the difference between mutable and immutable data types with examples.
#
# -->In Python, mutable and immutable refer to whether an object can be changed after it is created.
#
# Mutable Data Types
# •	Can be changed after creation.
# •	You can modify, add, or remove elements without creating a new object
#
# Ex : list,dictionary,sets.
#
#
# Immutable Data Types
#
# Cannot be changed after creation.
# Any operation that tries to change the value will create a new object.
#
# Ex
# string,tuple,integer

# %% [markdown]
# 3. What are the main differences between lists and tuples in Python?
#
# --> List is mutable, meaning you can change, add, or remove items.
#
# Tuple is immutable, meaning once created, it cannot be changed.
#
# Lists use square brackets [ ], tuples use parentheses ( ).

# %% [markdown]
# 4. Describe how dictionaries store data.
#
# --> It stores the data in key value pair which is separated by a colon
#
#
#
# ```
# # This is formatted as code
# ```
# person = {"name": "Alice", "age": 30}
#
# # "name" → "Alice"
# # "age" → 30

# %% [markdown]
# 5. Why might you use a set instead of a list in Python?
#
# --> You might use a set instead of a list in Python when you need to:
#
# Remove duplicates automatically
#
# Check membership quickly (faster than lists)
#
# Perform set operations like union, intersection, and difference

# %%
# 6. What is a string in Python, and how is it different from a list?
# String
s = "hello"
print("str:",s)
# List
l = ['h', 'e', 'l', 'l', 'o']
print("list:",l)
# Out:
# str: hello
# list: ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# 8.

# %% [markdown]
# 7. How do tuples ensure data integrity in Python?
#
# --> Tuples ensure data integrity in Python because they are immutable
#  meaning:
# Once created their values cannot be changed.
#
# making them useful for storing fixed information.

# %% [markdown]
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#
# --> A hash table stores data as key-value pairs using a hash function for fast access.
#
# In short:
# Python dictionaries use hash tables to provide quick lookups, inserts, and deletions based on keys.

# %% [markdown]
# 9. Can lists contain different data types in Python?
#
# --> Yes, lists in Python can contain different data types.
# EX
# an integer
# string
# a float
# a boolean
# another list such as ([1, 2, 3])
#
# This flexibility is one of the powerful features of Python lists
#
#
#
# ```
# # This is formatted as code
# ```
#
# [10, 'hello', 3.14, True, [1, 2, 3]]

# %% [markdown]
# 10. Explain why strings are immutable in Python.
#
#
#  --> Strings are immutable in Python to ensure safety, memory efficiency, and to allow them to be used as dictionary keys or in sets, since only immutable objects can be hashed(#)
#
#
#
# ```
# # This is formatted as code
# ```
# s = "hello"
# s[0] = "H"  #This will raise an error
#
#  'str' object does not support item assignment.

# %% [markdown]
# 11. What advantages do dictionaries offer over lists for certain tasks?
#
#
# --> Dictionaries offer faster lookups and direct access to data using keys, making them ideal for tasks like storing and retrieving values by name, ID, or label — unlike lists, which require searching by index.

# %% [markdown]
# 12. Describe a scenario where using a tuple would be preferable over a list.
#
# --> A tuple would be preferable over a list when you need to store a collection of items that should not change throughout the program,
# Since tuples are immutable, using them helps ensure the data remains constant and protected from accidental modification.
#
# Dates (year, month, day)
# RGB color values
# Configuration settings
# Pairs of related values (like database key-value pairs)

# %% [markdown]
# 13. How do sets handle duplicate values in Python?
#
# --> In Python sets automatically remove duplicate values and only store unique elements. If addedduplicate items to a set, any duplicates are ignored and only one instance of each unique value is kept
#
#
#
# ```
# # This is formatted as code
# ```
#
#
# s = {1, 2, 2, 3}
# print(s)  # Output: {1, 2, 3}

# %% [markdown]
# 14. How does the "in" keyword work differently for lists and dictionaries?
#
# --> List: in checks if a value exists in the list.
# ```
# colors = ['red', 'green', 'blue']
# print('green' in colors)  # ✅ True
# print('yellow' in colors) # ❌ False
# ```
#
#
# Dictionary: in checks if a key exists in the dictionary.
#
#
# ```
# car = {'brand': 'Toyota', 'year': 2020}
# print('brand' in car)  # ✅ True
# print('Toyota' in car) # ❌ False
# ```

# %% [markdown]
# 15. Can you modify the elements of a tuple? Explain why or why not.
#
# --> tuples are immutable meaning once they are created their elements cannot be changed added or removed.
# This immutability ensures data integrity and allows tuples to be used as keys in dictionaries or elements in sets.
#
# ```
# t = (10, 20, 30)
# t[1] = 99  #  This will raise a TypeError
# ```

# %% [markdown]
# 16. What is a nested dictionary, and give an example of its use case?
#
# --> A nested dictionary is a dictionary where values themselves are dictionaries.
# It allows you to store hierarchical or grouped data in a structured way.
#
#
# ```
# products = {
#     'P001': {'name': 'Laptop', 'price': 60000, 'stock': 15},
#     'P002': {'name': 'Phone', 'price': 30000, 'stock': 50}}
#
# print(products['P001']['stock'])  # Output: 15
# ```

# %% [markdown]
# 17. Describe the time complexity of accessing elements in a dictionary.
#
# --> Python dictionaries are implemented using hash tables.
# Accessing a value by key (e.g. my_dict['name']) is very fast because it uses the key’s hash to find the value directly.
#
# Many keys have the same hash (hash collisions).
# Python has to scan multiple entries degrading performance.
#
# However Python handles collisions efficiently so worst-case time is very rare.

# %% [markdown]
# 18. In what situations are lists preferred over dictionaries?
#
# --> lists preferred when:
# 	•	You need ordered data
# 	•	You want to access items by index
# 	•	You allow duplicate values
# 	•	You don’t need key-value pairs

# %% [markdown]
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#
# --> Dictionaries are called unordered because you don’t get items by position like in a list.
#
# Instead, you get values using keys (like my_dict['name']) so the order doesn’t matter for finding data.
#
# They are still not designed for position-based access (like lists).
# You retrieve values by key, not by position.
# So, the order doesn’t affect data retrieval, as lookup is always by key, not index.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
#
#
# -->. •	List:
# You get data using an index number (position)
#
# ```
# my_list = ['kiwi', 'dragon fruit', 'cherry']
# print(my_list[1])
#   # Output :dragon fruit
# ```
#
# •	Dictionary:
# You get data using a key (like a label or name).
#
# my_dict = {'fruit1': 'kiwi', 'fruit2': 'dragon fruit'}
# print(my_dict['fruit2'])
#
# output: dragon fruit
